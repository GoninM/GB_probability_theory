# %%
from math import exp, sqrt

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from math import pi

# %% [markdown]
# #### 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800]. Найдите ее среднее значение и дисперсию.

# %%
b = 800
a = 200

# %%
mx = (b+a)/2
mx
# Out:
# 500.0

# %%
dx = (b-a)**2/12
dx
# Out:
# 30000.0

# %% [markdown]
# #### 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %%
dx = 0.2
a = 0.5

# %%
b = sqrt(dx*12)+a
b
# Out:
# 2.049193338482967

# %%
mx = (b+a)/2
mx
# Out:
# 1.2745966692414834

# %% [markdown]
# #### 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения f(x) = (1 / (4 * sqrt(2pi))) * exp((-(x+2)**2) / 32) Найдите:
# #### а). M(X)
# #### б). D(X)
# #### в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e ^ {- \frac{(x - a)^2}{2 \sigma^2}},$$
# где $a = M(X), \; \sigma^2 = D(X).$

# %% [markdown]
# Формула из задания:
# $$f(x) = \frac{1}{4 \sqrt{2 \pi}} e ^ {- \frac{(x + 2)^2}{32}} = \frac{1}{4 \sqrt{2 \pi}} e ^ {- \frac{(x - (-2))^2}{2*4^2}}$$

# %% [markdown]
# Ответ:
# $$M(X) = -2$$
# $$D(x) = 16$$
# $$std(x) = \sqrt{D(x)} = \sqrt{16} = 4$$

# %% [markdown]
# #### 4. Рост взрослого населения города X имеет нормальное распределение. Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см. Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# #### а). больше 182 см
# #### б). больше 190 см
# #### в). от 166 см до 190 см
# #### г). от 166 см до 182 см
# #### д). от 158 см до 190 см
# #### е). не выше 150 см или не ниже 190 см
# #### ё). не выше 150 см или не ниже 198 см
# #### ж). ниже 166 см.

# %% [markdown]
# ### Решение через таблицы:

# %% [markdown]
# <img src="https://ok-t.ru/studopediaru/baza4/2367314978102.files/image919.jpg" width=600 height=600/>

# %%
#ищу Z потом по табличке значение.
#средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см
h_mean = 174
h_std = 8

#а). больше 182 см**
Z1 = (182 - 174)/8
p = round(0.1587*100, 3)
print(f'а). больше 182 см: Z = {Z1}, p = {p}%')

# б). больше 190 см
Z1 = (190 - 174)/8
p = round(0.0228*100, 3)
print(f'б). больше 190 см: Z = {Z1}, p = {p}%')

# в). от 166 см до 190 см
Z1 = (166 - 174)/8
Z2 = (190 - 174)/8
p1 = round(0.1587*100, 3)
p2 = round((1-0.0228)*100, 3)
print(f'в). от 166 см до 190 см: Z1 = {Z1} Z2 = {Z2}, p1 = {p1}%, p2 = {p2}%, p = p2-p1 = {p2-p1}% ')

# г). от 166 см до 182 см
Z1 = (166 - 174)/8
Z2 = (182 - 174)/8
p1 = round(0.1587*100, 3)
p2 = round((1-0.1587)*100, 3)
print(f'г). от 166 см до 182 см: Z1 = {Z1} Z2 = {Z2}, p1 = {p1}%, p2 = {p2}%, p = p2-p1 = {round(p2-p1, 3)}% ')

# д). от 158 см до 190 см
Z1 = (158 - 174)/8
Z2 = (190 - 174)/8
p1 = round(0.0228*100, 3)
p2 = round((1-0.0228)*100, 3)
print(f'д). от 158 см до 190 см: Z1 = {Z1} Z2 = {Z2}, p1 = {p1}%, p2 = {p2}%, p = p2-p1 = {round(p2-p1, 3)}% ')

# е). не выше 150 см или не ниже 190 см
Z1 = (150 - 174)/8
Z2 = (190 - 174)/8
p1 = round(0.0013*100, 3)
p2 = round((0.0228)*100, 3)
print(f'е). не выше 150 см или не ниже 190 см: Z1 = {Z1} Z2 = {Z2}, p1 = {p1}%, p2 = {p2}%, p = p2+p1 = {round(p2+p1, 3)}% ')

# ё). не выше 150 см или не ниже 198 см
Z1 = (150 - 174)/8
Z2 = (198 - 174)/8
p1 = round(0.0013*100, 3)
p2 = round((0.0013)*100, 3)
print(f'ё). не выше 150 см или не ниже 198 см: Z1 = {Z1} Z2 = {Z2}, p1 = {p1}%, p2 = {p2}%, p = p2+p1 = {round(p2+p1, 3)}% ')

# ж). ниже 166 см.
Z1 = (166 - 174)/8
p = round(0.1587*100, 3)
print(f'ж). ниже 166 см: Z = {Z1}, p = {p}%')
# Out:
# а). больше 182 см: Z = 1.0, p = 15.87%
# б). больше 190 см: Z = 2.0, p = 2.28%
# в). от 166 см до 190 см: Z1 = -1.0 Z2 = 2.0, p1 = 15.87%, p2 = 97.72%, p = p2-p1 = 81.85%
# г). от 166 см до 182 см: Z1 = -1.0 Z2 = 1.0, p1 = 15.87%, p2 = 84.13%, p = p2-p1 = 68.26%
# д). от 158 см до 190 см: Z1 = -2.0 Z2 = 2.0, p1 = 2.28%, p2 = 97.72%, p = p2-p1 = 95.44%
# е). не выше 150 см или не ниже 190 см: Z1 = -3.0 Z2 = 2.0, p1 = 0.13%, p2 = 2.28%, p = p2+p1 = 2.41%
# ё). не выше 150 см или не ниже 198 см: Z1 = -3.0 Z2 = 3.0, p1 = 0.13%, p2 = 0.13%, p = p2+p1 = 0.26%
# ж). ниже 166 см: Z = -1.0, p = 15.87%

# %% [markdown]
# ### Проба использовать готовые библиотеки.

# %%
from scipy.stats import norm

# %%
def draw_graf(x, mean, std, condition, string):
    plt.plot(x, norm.pdf(x, loc=mean, scale=std))
    plt.grid(True)
    
    px = x[condition]
    plt.fill_between(px, 0, norm.pdf(px, loc=mean, scale=std), alpha = 0.2, color = 'b')
    
    plt.title(f'{string}', fontsize=20)

    plt.show()

# %%
height_mean = 174
height_std = 8
x = np.linspace(100,250,10000)

# %% [markdown]
# #### а). больше 182 см

# %%
x1 = 182

p = round(100*norm.sf(x=x1, loc=height_mean, scale=height_std), 2)
result = f"а). больше 182 см: {p}%" 

condition = (x >= x1)


draw_graf(x, height_mean, height_std, condition, result)

# %% [markdown]
# #### б). больше 190 см

# %%
x1 = 190

p = round(100*norm.sf(x=x1, loc=height_mean, scale=height_std), 2)
result = f"б). больше 190 см: {p}%" 

condition = (x >= x1)

draw_graf(x, height_mean, height_std, condition, result)

# %% [markdown]
# #### в). от 166 см до 190 см

# %%
x1 = 166
x2 = 190

p = round(100*(norm(height_mean, height_std).cdf(x2) - norm(height_mean,height_std).cdf(x1)), 2)
result = f"в). от 166 см до 190 см: {p}%" 

condition = ((x >= x1) & (x<=x2))

draw_graf(x, height_mean, height_std, condition, result)

# %% [markdown]
# #### г). от 166 см до 182 см

# %%
x1 = 166
x2 = 182

p = round(100*(norm(height_mean, height_std).cdf(x2) - norm(height_mean,height_std).cdf(x1)), 2)
result = f"г). от 166 см до 182 см: {p}%" 

condition = ((x >= x1) & (x<=x2))

draw_graf(x, height_mean, height_std, condition, result)

# %% [markdown]
# #### д). от 158 см до 190 см

# %%
x1 = 158
x2 = 190

p = round(100*(norm(height_mean, height_std).cdf(x2) - norm(height_mean,height_std).cdf(x1)), 2)
result = f"д). от 158 см до 190 см: {p}%" 

condition = ((x >= x1) & (x<=x2))

draw_graf(x, height_mean, height_std, condition, result)

# %% [markdown]
# #### е). не выше 150 см или не ниже 190 см

# %%
x1 = 150
x2 = 190

p = round(100*(norm(height_mean,height_std).cdf(x1) + norm.sf(x=x2, loc=height_mean, scale=height_std)), 2)
result = f"е). не выше 150 см или не ниже 190 см: {p}%" 

plt.plot(x, norm.pdf(x, loc=height_mean, scale=height_std))
plt.grid(True)

px = x[(x <= x1)]
plt.fill_between(px, 0, norm.pdf(px, loc=height_mean, scale=height_std), alpha = 0.2, color = 'b')

px = x[(x>=x2)]
plt.fill_between(px, 0, norm.pdf(px, loc=height_mean, scale=height_std), alpha = 0.2, color = 'b')

plt.title(f'{result}', fontsize=20)

plt.show()

# %% [markdown]
# #### ё). не выше 150 см или не ниже 198 см

# %%
x1 = 150
x2 = 198

p = round(100*(norm(height_mean,height_std).cdf(x1) + norm.sf(x=x2, loc=height_mean, scale=height_std)), 2)
result = f"ё). не выше 150 см или не ниже 198 см: {p}%" 

plt.plot(x, norm.pdf(x, loc=height_mean, scale=height_std))
plt.grid(True)

px = x[(x <= x1)]
plt.fill_between(px, 0, norm.pdf(px, loc=height_mean, scale=height_std), alpha = 0.2, color = 'b')

px = x[(x>=x2)]
plt.fill_between(px, 0, norm.pdf(px, loc=height_mean, scale=height_std), alpha = 0.2, color = 'b')

plt.title(f'{result}', fontsize=20)

plt.show()

# %% [markdown]
# #### ж). ниже 166 см.

# %%
x1 = 166

p = round(100*norm.cdf(x=x1, loc=height_mean, scale=height_std), 2)
result = f"ж). ниже 166 см.: {p}%" 

condition = (x <= x1)


draw_graf(x, height_mean, height_std, condition, result)

# %% [markdown]
# #### 5. На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
n = (190 - 178)/sqrt(25)
n
# Out:
# 2.4
